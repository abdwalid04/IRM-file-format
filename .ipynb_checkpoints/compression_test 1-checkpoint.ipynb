# %%
from matplotlib.pylab import plt
import numpy as np
import pickle
from PIL import Image
from imshowpair import imshowpair
import os

# %%
def ReadImage(path):
    img = Image.open(path)
    c_img = img.quantize(method=0,colors=256) 
    palette = c_img.getpalette()
    a_img = np.array(c_img)
    return a_img,palette
def img_to_txt(I):
    sh = I.shape
    im = I.flatten()
    T = ''
    for i in im:
        T += chr(int(i))
    return T,sh

def txt_to_img(T,sh):
    M = []
    for i in T:
        M.append(ord(i))
    return np.array(M).reshape(sh)
def codage_LZW(M):
    w = ""
    code = []
    dict_size = 256
    D = {chr(i): i for i in range(dict_size)}
    for c in M:
        wc = w + c
        if wc in D:
            w = wc
        else:
            code.append(D[w])
            D[wc] = dict_size
            dict_size += 1
            w = c
    if w:
        code.append(D[w])
    return code
def decodage_LZW(M):
    dict_size = 256
    D = {i: chr(i) for i in range(dict_size)}
    w = chr(M[0])
    M = M[1:]
    code = w
    e = w
    for i in M:
        if i in D.keys():
            e = D[i]
        elif i == dict_size:
            e = w + w[0]
        code += e
        D[dict_size] = w + e[0]
        dict_size += 1
        w = e
    return code
def LZW_img(I,op):
    if op == "decodage":
        i_img = txt_to_img(decodage_LZW(I[770:]),I[:2])
        c_img = Image.fromarray(i_img.astype(np.uint8),"P")
        c_img.putpalette(I[2:770].tolist(),rawmode="RGB")
        return c_img.convert("RGB")
    elif op == "codage":
        C = img_to_txt(I[0])
        CC = []
        CC.extend(C[1])
        CC.extend(I[1])
        CC.extend(codage_LZW(C[0]))
        return np.array(CC)

# %%
img = ReadImage("sample_1920×1280.bmp")
L = LZW_img(img,"codage")

# %%
L
# Out:
# array([  1280,   1920,    254, ..., 458249, 304895, 444468])

# %%
with open("hh.irm",'wb') as op:
    op.write(L.tobytes())

# %%
with open("hh.irm",'rb') as op:
    res = np.frombuffer(op.read(),dtype=int)

# %%
res
# Out:
# array([  1280,   1920,    254, ..., 458249, 304895, 444468])

# %%
f = np.array(LZW_img(res,"decodage"))

# %%
i = np.array(Image.open("sample_1920×1280.bmp"))

# %%
plt.figure(figsize=(40,50))
imshowpair(i,f)

# %%
def tauxCompression(pathOriginal,pathCompresse):
    i=os.path.getsize(pathOriginal)
    f=os.path.getsize(pathCompresse)
    taux=1-(f/i)
    return np.round(taux*100,2)

tauxCompression('sample_1920×1280.bmp','hh.irm')
# Out:
# 63.11

# %%
def errquadra(i,f):
    z=np.mean((i-f)**2)
    return z

errquadra(i,f)
# Out:
# 24.330552707248263

# %%
def SNR(i,f):
    v=np.mean(i**2)
    mse=errquadra(i,f)
    z=10*np.log(v/mse)
    return z


SNR(i,f)
# Out:
# 14.396060127924866

# %%
def PSNR(i,f):
    m=np.max(i**2)
    mse=errquadra(i,f)
    z=10*np.log(m/mse)
    return z


PSNR(i,f)
# Out:
# 23.257200228188694
