# %%
import numpy as np
import cv2
from matplotlib.pylab import plt

# %%
img = plt.imread("sample_1920×1280.bmp")
plt.imshow(img)

# %%
yuv = cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22f82f312a4f> in <module>
# ----> 1 yuv = cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb)
#
# NameError: name 'cv2' is not defined

# %%
plt.imshow(yuv)

# %%
img[:3,0,:3]
# Out:
# array([[175, 129, 140],
#        [181, 135, 146],
#        [173, 127, 138]], dtype=uint8)

# %%
yuv[:3,0,:3]
# Out:
# array([[144, 150, 126],
#        [150, 150, 126],
#        [142, 150, 126]], dtype=uint8)

# %%
y = cv2.cvtColor(yuv, cv2.COLOR_YCrCb2RGB)

# %%
plt.imshow(y)
